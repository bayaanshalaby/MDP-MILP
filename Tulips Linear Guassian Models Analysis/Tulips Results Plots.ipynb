# %% [markdown]
# # Tulips Results

# %%
import numpy as np
# %run GenerateAndPlotModels.py

# %% [markdown]
# ## Model 1: Maximizing Stem Height

# %%
samples = np.logspace(start = 10, stop = 15, base = 2, num = 6)

generateStemModels(samples, 100)
# Out:
# Generated 100 Stem Models for n = 1024.0
# Generated 100 Stem Models for n = 2048.0
# Generated 100 Stem Models for n = 4096.0
# Generated 100 Stem Models for n = 8192.0
# Generated 100 Stem Models for n = 16384.0
# Generated 100 Stem Models for n = 32768.0
# Completed generating all Stem Models.

# %%
plotStemVariable('Tulip Type', 'r')

# %%
plotStemVariable('Amount of Water', 'b')

# %%
plotStemVariable('Objective Function Value', 'Purple')

# %%
plotStemVariable('Sampled Reward', 'g')

# %%
plotStemVariable('Runtime', 'Black')

# %%
plotStemVariable('Optimization Time', 'Black')

# %%
plotStemVariable('Simplex Iterations', 'Black')

# %% [markdown]
# ## Model 2: Maximizing Stem + Flower Height

# %%
samples = np.logspace(start = 10, stop = 15, base = 2, num = 6)

generateStemFlowerModels(samples, 100)
# Out:
# Generated 100 Stem Flower Models for n = 1024.0
# Generated 100 Stem Flower Models for n = 2048.0
# Generated 100 Stem Flower Models for n = 4096.0
# Generated 100 Stem Flower Models for n = 8192.0
# Generated 100 Stem Flower Models for n = 16384.0
# Generated 100 Stem Flower Models for n = 32768.0
# Completed generating all Stem Flower Models.

# %%
plotStemFlowerVariable('Tulip Type', 'r')

# %%
plotStemFlowerVariable('Amount of Water', 'b')

# %%
plotStemFlowerVariable('Outdoor', 'y')

# %%
plotStemFlowerVariable('Objective Function Value', 'Purple')

# %%
plotStemFlowerVariable('Sampled Reward', 'g')

# %%
plotStemFlowerVariable('Runtime', 'Black')

# %%
plotStemFlowerVariable('Optimization Time', 'Black')

# %%
plotStemFlowerVariable('Simplex Iterations', 'Black')

# %% [markdown]
# ## Model 3: Maximizing Stem + Flower + Roots Length

# %%
samples = np.logspace(start = 10, stop = 15, base = 2, num = 6)

generateStemFlowerRootsModels(samples, 100)
# Out:
# Generated 100 Stem Flower Roots Models for n = 1024.0
# Generated 100 Stem Flower Roots Models for n = 2048.0
# Generated 100 Stem Flower Roots Models for n = 4096.0
# Generated 100 Stem Flower Roots Models for n = 8192.0
# Generated 100 Stem Flower Roots Models for n = 16384.0
# Generated 100 Stem Flower Roots Models for n = 32768.0
# Completed generating all Stem Flower Roots Models.

# %%
plotStemFlowerRootsVariable('Tulip Type', 'r')

# %%
plotStemFlowerRootsVariable('Amount of Water', 'b')

# %%
plotStemFlowerRootsVariable('Outdoor', 'y')

# %%
plotStemFlowerRootsVariable("Pellets", 'Brown')

# %%
plotStemFlowerRootsVariable('Objective Function Value', 'Purple')

# %%
plotStemFlowerRootsVariable('Sampled Reward', 'g')

# %%
plotStemFlowerRootsVariable('Runtime', 'Black')

# %%
plotStemFlowerRootsVariable('Optimization Time', 'Black')

# %%
plotStemFlowerRootsVariable('Simplex Iterations', 'Black')
